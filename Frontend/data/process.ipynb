# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("0515_Feature_Extraction.csv")
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x       forum  year            decision  \
# 0             0             0  B1e-kxSKDH  2020     Accept (Poster)
# 1             1             1  B1e3OlStPB  2020  Accept (Spotlight)
# 2             2             2  B1e5TA4FPr  2020              Reject
# 3             3             3  B1e9Y2NYvS  2020  Accept (Spotlight)
# 4             4             4  B1eBoJStwr  2020              Reject
#
#    avg_score                                       INTRODUCTION  \
# 0   6.000000  Obtaining structured knowledge about the world...
# 1   6.666666  Spherical data is found in many applications (...
# 2   3.000000  Machine learning algorithms play an important ...
# 3   6.666666  Neural ordinary differential equations (Chen e...
# 4   3.000000  Semi-supervised learning offers the tantalizin...
#
#                                           CONCLUSION  \
# 0  We introduced STOVE, a structured, object-awar...
# 1  This work showed that DeepSphere strikes an in...
# ...
